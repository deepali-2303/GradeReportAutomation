# %%
import pandas as pd

# %%
df = pd.read_csv('merged_df.csv')
df
# Out:
#            UID                             Name  SGPA_1 Results_1  SGPA_2  \
# 0   2018120014  CONTRACTOR VARUN MANOJ DARSHANA     NaN       NaN     NaN
# 1   2018120016                      DATTA SOHEL     NaN       NaN     NaN
# 2   2018120018        DHODI NIRAJ SURESH SUNITA     NaN       NaN     NaN
# 3   2018120047       PATEL SHIVAM DHANSUKH RITA     NaN       NaN     NaN
# 4   2018120059      TRUPTI GOPINATH JAYALAKSHMI     NaN       NaN     NaN
# ..         ...                              ...     ...       ...     ...
# 81  2020201070     PANCHAL UTSAV SURESH SANGITA     NaN       NaN     NaN
# 82  2020201071     SASANE SUJANT DINESH DEEPALI     NaN       NaN     NaN
# 83  2020201072  SAYED MOHAMMED SAUD NISAR ALMAS     NaN       NaN     NaN
# 84  2020201073   SHINDE SARVESHA RAJENDRA DEEPA     NaN       NaN     NaN
# 85  2020201074     THORAT RUTUJA RAMESH KALPANA     NaN       NaN     NaN
#
#    Results_2    SGPA_3 Results_3    SGPA_4 Results_4  SGPA_5 Results_5  \
# ...
